# %% [markdown]
# <a href="https://colab.research.google.com/github/Erick-Cavalcante/multiple-linear-regression-model/blob/main/multiple_linear_regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #https://www.kaggle.com/datasets/shivamb/netflix-shows

# %%
import pandas as pd
# !wget -q  'https://raw.githubusercontent.com/Erick-Cavalcante/statistical_model/refs/heads/main/Spotify%20Most%20Streamed%20Songs.csv' -O SpotifyMostStreamedSongs

spotify= pd.read_csv('SpotifyMostStreamedSongs')
spotify.head(20)
# Out:
#                                            track_name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 1                                                LALA
# 2                                             vampire
# 3                                        Cruel Summer
# 4                                      WHERE SHE GOES
# 5                                            Sprinter
# 6                                     Ella Baila Sola
# 7                                            Columbia
# 8                                            fukumean
# 9                                     La Bebe - Remix
# 10                                          un x100to
# 11                                          Super Shy
# 12                                            Flowers
# 13                                           Daylight
# 14                                          As It Was
# 15                                          Kill Bill
# ...

# %%
spotify[['artist(s)_name', 'released_month', 'in_spotify_playlists', 'in_apple_playlists streams']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-a4eee5d32c25> in <cell line: 1>()
# ----> 1 spotify[['artist(s)_name', 'released_month', 'in_spotify_playlists', 'in_apple_playlists streams']].head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...
